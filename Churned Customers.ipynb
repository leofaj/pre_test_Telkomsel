# %% [markdown]
# <br> **Pre Test Telkomsel Data Science Academy**
# <br> 16 October 2019
# <br> Leo Fajri

# %%
import numpy as np
import pandas as pd

# %%
churn= pd.read_csv('churn.csv')

# %%
churn.head()
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %% [markdown]
#  Which top 5 state have most customers

# %%
churn["state"].value_counts()
# Out:
# 49    158
# 23    125
# 1     124
# 13    119
# 45    118
# 35    116
# 43    116
# 50    115
# 34    114
# 37    114
# 44    112
# 31    112
# 48    106
# 19    103
# 21    103
# 22    103
# 20    102
# 46    101
# 16     99
# 17     99
# 26     99
# 25     99
# 39     99
# 6      99
# 47     98
# 15     98
# 5      96
# 30     95
# 8      94
# 24     93
# 2      92
# 40     91
# 27     91
# 32     91
# 33     90
# 9      90
# 36     90
# 42     89
# 3      89
# 28     88
# 7      88
# 29     88
# 14     88
# 11     86
# 41     85
# 10     83
# 18     82
# 38     77
# 0      72
# 12     69
# 4      52
# Name: state, dtype: int64

# %%
churn.sample(n=100,random_state=10)
# Out:
#       state  account_length  area_code  phone_number  international_plan  \
# 245      40              22        408           188                   0
# 4493     46              83        510          3540                   0
# 4583     21             104        415          4068                   0
# 2242      5             192        415          3875                   0
# 3407      5              93        415          1000                   0
# 807      10              56        415          4723                   0
# 693      31              92        510          4924                   0
# 515      13             148        510          4941                   0
# 3224     15             115        415          2269                   0
# 549      36             121        408          1916                   0
# 4846      2             112        510          3492                   0
# 3863     47              49        510          4186                   0
# ...

# %%
import statistics as st

# %%
mode
# Out:
#   File "<ipython-input-24-8e04e9e4cb87>", line 2
#     churn_class1=churn[churn.class == '1']
#                                  ^
# SyntaxError: invalid syntax

# %%
st.median(churn.number_customer_service_calls)
# Out:
# 1.0

# %%
st.mean(churn.number_customer_service_calls)
# Out:
# 1.5704

# %%
churn['call_cs']=np.where(churn['number_customer_service_calls']>1,'high','low')

# %%
churn.head()
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_eve_charge  total_night_minutes  \
# ...

# %%
churn["call_cs"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        low
# 1        low
# 2        low
# 3        low
# 4       high
# 5        low
# 6       high
# 7        low
# 8        low
# 9        low
# 10      high
# 11       low
# 12       low
# 13      high
# 14      high
# 15      high
# 16       low
# 17      high
# 18       low
# 19       low
# 20       low
# 21      high
# 22       low
# 23       low
# 24       low
# 25      high
# 26       low
# 27      high
# 28       low
# 29       low
#         ...
# 4970     low
# 4971     low
# 4972     low
# 4973     low
# 4974     low
# 4975     low
# 4976     low
# 4977     low
# 4978    high
# 4979     low
# 4980    high
# 4981     low
# 4982    high
# 4983     low
# 4984     low
# 4985    high
# 4986    high
# 4987     low
# 4988     low
# 4989     low
# 4990     low
# 4991     low
# 4992     low
# 4993    high
# 4994     low
# 4995     low
# 4996    high
# 4997     low
# 4998     low
# 4999     low
# ...

# %%
st.median(churn.total_day_charge)
# Out:
# 30.62

# %%
st.mean(churn.total_day_charge)
# Out:
# 30.649668

# %%
churn['charge']=np.where(churn['total_day_charge']>30,'low','high')

# %%
churn.head()
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_night_minutes  total_night_calls  \
# ...

# %%
fn = lambda x: x.sample(n=10, random_state=10, replace=False)
churn = churn.groupby('call_cs', as_index=False).apply(fn)

# %%
st.median(churn.total_day_minutes)
# Out:
# 166.4

# %%
churn['minutes calls']=np.where(churn['total_day_minutes']>166,'high','low')

# %%
churn.head()
# Out:
#         state  account_length  area_code  phone_number  international_plan  \
# 0 2733     32             158        408          2570                   0
#   2199     47             110        415          4785                   0
#   2588     22              53        510          4739                   0
#   4859     25              95        510          4710                   0
#   4582     38              25        415          2645                   0
#
#         voice_mail_plan  number_vmail_messages  total_day_minutes  \
# 0 2733                0                      0              172.4
#   2199                0                      0              241.2
#   2588                1                     37              167.3
#   4859                1                     44              173.3
#   4582                0                      0              195.2
#
#         total_day_calls  total_day_charge  ...  total_night_calls  \
# ...
